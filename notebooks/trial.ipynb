# %%
from settings import HANDPOSE_MODEL_CONFIG
from io_ import get_model_file

model_name = HANDPOSE_MODEL_CONFIG["model_name"]
model_fp = get_model_file(model_name=model_name)

# %%
from model.inference import ExternalHand

hand = ExternalHand(file_name="redscreen.jpg", config=HANDPOSE_MODEL_CONFIG)

# %%
hand.plot_pred_skeleton()
